# %%
Balance= 10000
pin= 785089
attempt= 0

while attempt<3 :
    Pass= int(input("Enter Password :"))
    if Pass==pin:
        print("Access Granted")
        print("""
        1. Cash Deposit
        2. Withdraw Money
        3. Check Balance
        4. Exit
        """)
        choice=int(input("Enter your choice :"))
        if choice==2:
            amount=int(input("Enter Ammount to withdraw:"))
            if amount < Balance :
                Balance -= amount
                print("Withdrawal Successfully")
                print("Remaining Balance :",Balance)
            else:
                print("Insufficient Balance")
        elif choice==1:
            amount=int(input("Enter Ammount to Deposit:"))
            Balance += amount
            print("Current Balance is :",Balance)
        elif choice==3:
            print("Current Balance :",Balance)
        elif choice==4:
            print("Byy byy")
            break
    else:
        attempt += 1
        print(f"{3-attempt} Attempt left")
# Out:
# Enter Password : 785089
# Access Granted
#
#         1. Cash Deposit
#         2. Withdraw Money
#         3. Check Balance
#         4. Exit
# Enter your choice : 1
# Enter Ammount to Deposit: 200
# Current Balance is : 10200
# Enter Password : 785089
# Access Granted
#
#         1. Cash Deposit
#         2. Withdraw Money
#         3. Check Balance
#         4. Exit
# Enter your choice : 4
# Byy byy
