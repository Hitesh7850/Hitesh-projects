# %%
a=float(input("Enter a Hours :"))
b=a*60*60
print(f"{a} Hours = {b} Second")
# Out:
# Enter a Hours : 1
# 1.0 Hours = 3600.0 Second

# %%
a=float(input("Enter kilogram :"))
b=a*2.21
print(f"{a} kilo = {b} Pounds")
# Out:
# Enter kilogram : 1
# 1.0 kilo = 2.21 Pounds

# %%
a=float(input("Enter miles :"))
b=a*1.61
print(f"{a} miles = {b} Kilometer ")
# Out:
# Enter miles : 10
# 10.0 miles = 16.1 Kilometer

# %%
c= float(input("Enter the Temperature :"))
f= float(input("Enter the temperature2 :"))
a= float((c*1.8)+32)
b=float((f-32)*5/9)
print("your temp in f is :",a)
print("your temp in c is :",b)

# %%
a=float(input("Enter a Hours :"))
b=a*60
print(f"{a} Hours = {b} minutes")
