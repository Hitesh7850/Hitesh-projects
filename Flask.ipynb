# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def home():
    return """
    <h1> I am Home page By HITESH </h1>
    <h2> I am running in flask </h2>
    <html>
    <head>
        <title>My Simple Page</title>
    </head>
    <body>
    
        <h1>Hello World!</h1>
        <p>This is my first simple HTML page.</p>
    
    </body>
    </html>
    """
if __name__=='__main__':
    app.run()

@app.route("/about")
def abouta():
    return """
    <h1> I am Home page By HITESH </h1>
    <h2> I am running in flask </h2>
    <html>
    <head>
        <title>My Simple Page</title>
    </head>
    <body>
    
        <h1>Hello World!</h1>
        <p>This is my first simple HTML page.</p>
    
    </body>
    </html>
    """
if __name__=='__main__':
    app.run()

if __name__=='__main__':
    app.run(debug=True)
