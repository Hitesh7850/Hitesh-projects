# %%
age=int(input("Enter your age :"))
if age>18:
    print("Take your id ")
    ticket =str(input("have you a ticket ..?"))    
    if ticket== 'yes':
        print("You can go inside ")
        print("You can watch movie ")
    else :
        print("Please take ticket")
elif age<18:
    print("you can watch movie but only with parents ")
else :
    print("Not Allowed ")
