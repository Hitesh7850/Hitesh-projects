# %%
import pywhatkit
pywhatkit.sendwhatmsg_instantly("Enter your WhatsApp no.","Hii Divyanshu sending from Python") #Enter your own WhatsApp no.
pywhatkit.sendwhatmsg("Enter sender no.","Hii Divyanshu sending from Python")
